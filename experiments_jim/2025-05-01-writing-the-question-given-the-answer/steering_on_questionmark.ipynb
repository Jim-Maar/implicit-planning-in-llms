# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 23 10:57:41 2025

@author: Paper001
"""
import dotenv
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from dataclasses import dataclass

# from utils.data_generation.a_an_data import datasets

import gc
from contextlib import contextmanager
from typing import List, Dict, Optional, Callable
import einops
from tqdm import tqdm

from utils.data import (
    a_an_something_questions,
    a_habit_questions,
    a_rabbit_questions,
    an_ape_questions,
    lines_that_rhyme_with_pain,
    lines_that_rhyme_with_quick,
    example_based_rhymed_prompts_quick,
    example_based_unrhymed_prompts_quick,
    rhymed_couplets,
    unrhymed_couplets,
    lines_that_rhyme_with_rabbit,
    lines_that_rhyme_with_habit,
    lines_that_rhyme_with_rabbit_general,
    lines_that_rhyme_with_rabbit_oneshot,
    lines_that_rhyme_with_habit_general,
    lines_that_rhyme_with_habit_oneshot,
    a_pear_or_an_apple_questions,
    a_pear_questions,
    an_apple_questions,
    a_date_questions,
    a_date_or_a_pear_questions,
    rhymed_couplets_one_shoot,
    unrhymed_couplets_one_shoot,
)

print(f"PyTorch version: {torch.__version__}")
print(f"Transformers version: {transformers.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"Current device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
# %%
dotenv.load_dotenv("hf.env")
# @title 1.5. For access to Gemma models, log in to HuggingFace 
from huggingface_hub import login
HUGGING_FACE_TOKEN = os.getenv("HUGGINGFACE_TOKEN")
try:
     login(token=HUGGING_FACE_TOKEN)
     print("Hugging Face login successful (using provided token).")
except Exception as e:
     print(f"Hugging Face login failed. Error: {e}")
# %%
MODEL_ID = "google/gemma-3-27b-it" # Or "google/gemma-2-9b" if you prefer the base model
# Set to True if you have limited VRAM (e.g., < 24GB). Requires bitsandbytes
USE_4BIT_QUANTIZATION = False

POSITIVE_PROMPTS = [
    "This story should be very optimistic and uplifting.",
    "Write a hopeful and positive narrative.",
    "Generate text with a cheerful and encouraging tone.",
]
NEGATIVE_PROMPTS = [
    "This story should be very pessimistic and bleak.",
    "Write a depressing and negative narrative.",
    "Generate text with a gloomy and discouraging tone.",
]

# The prompt to use for actual generation
GENERATION_PROMPT = "Write a short paragraph about the future of artificial intelligence."

# How strongly to apply the steering vector. Tune this value (e.g., 0.5 to 5.0)
STEERING_MULTIPLIER = 1.5

# --- Generation Parameters ---
MAX_NEW_TOKENS = 150
TEMPERATURE = 0.7
DO_SAMPLE = True
# Out:
# PyTorch version: 2.7.0+cu126
# Transformers version: 4.51.3
# CUDA available: True
# CUDA version: 12.6
# Current device: 0
# Device name: NVIDIA A100-SXM4-80GB
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Hugging Face login successful (using provided token).

# %%
words_rhyme_quick='''sick, tick, brick, click, trick, kick, thick, pick, stick, lick, flick, slick, wick, prick, chick, nick, clique, hick, shtick, arithmetic, candlestick, dipstick, gimmick, lipstick, maverick, picnic, politic, rhetoric, seasick, sidekick, toothpick, yardstick, Benedict, carsick, chopstick, heretic, homesick, joystick, lunatic, matchstick, nitpick, slapstick, drumstick, kinesthetic, statistic, dramatic, magnetic, Olympic, specific, terrific, acoustic, forensic'''.split()
words_rhyme_quick=[w.strip(',') for w in words_rhyme_quick]

words_rhyme_pain='''rain, main, train, plain, stain, brain, chain, gain, drain, Spain, lane, vain, cane, sane, bane, mane, crane, plane, strain, grain, Maine, Jane, reign, deign, feign, campaign, champagne, cocaine, contain, disdain, domain, explain, humane, inane, insane, maintain, membrane, migraine, mundane, profane, remain, restrain, retain, sustain, terrain, Ukraine, Bahrain, cellophane, entertain, hurricane, microphone, windowpane, abstain, again, arcane, complain, constrain, detain, dingbane, germane, Great Dane, inhumane, insane, mundane, novocaine, obtain, ordain, pertain, propane, refrain, urbane'''.split()
words_rhyme_pain=[w.strip(',') for w in words_rhyme_pain]


pain_rhymes1=[w.split()[-1] for w in lines_that_rhyme_with_pain[:23]]
pain_rhymes2=[w.split()[-1] for w in lines_that_rhyme_with_pain[23:]]

pain_rhymes_from_lines=list(set([w.split()[-1] for w in lines_that_rhyme_with_pain]))
quick_rhymes_from_lines=list(set([w.split()[-1] for w in lines_that_rhyme_with_quick]))

pain_rhymes_outside_lines=[w for w in words_rhyme_pain if w not in pain_rhymes_from_lines]
quick_rhymes_outside_lines=[w for w in words_rhyme_quick if w not in quick_rhymes_from_lines]

pain_rhymes_all=["pain"]+pain_rhymes_from_lines+pain_rhymes_outside_lines
quick_rhymes_all=["quick"]+quick_rhymes_from_lines+quick_rhymes_outside_lines


# %%
# ## 3. Load Model and Tokenizer

# +
# Configure quantization if needed
quantization_config = None
if USE_4BIT_QUANTIZATION:
    quantization_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.bfloat16 # Recommended for new models
    )
    print("Using 4-bit quantization.")

# Determine device and dtype
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.bfloat16 if torch.cuda.is_available() and torch.cuda.get_device_capability()[0] >= 8 else torch.float32 # BF16 recommended on Ampere+

print(f"Loading model: {MODEL_ID}")
print(f"Using device: {device}")
print(f"Using dtype: {dtype}")

# Load Tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token # Set pad token if not present

# Load Model
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    torch_dtype=dtype,
    quantization_config=quantization_config,
    # device=device,
    device_map="auto", # Automatically distribute across GPUs if available
    # use_auth_token=YOUR_HF_TOKEN, # Add if model requires authentication
    trust_remote_code=True # Gemma requires this for some versions/variants
)

print(f"Model loaded on device(s): {model.hf_device_map}")

# --- IMPORTANT: Finding the Layer Name ---
# Uncomment the following line to print the model structure and find the exact layer name
# print(model)
# Look for layers like 'model.layers[INDEX].mlp...' or 'model.layers[INDEX].self_attn...'

# Ensure model is in evaluation mode
model.eval()
# %%
# ## 4. Hooking and Activation Handling Functions

# +
# Global storage for captured activations
activation_storage = {}

def get_module_by_name(model, module_name):
    """Helper function to get a module object from its name string."""
    names = module_name.split('.')
    module = model
    for name in names:
        module = getattr(module, name)
    return module

def capture_activation_hook(module, input, output, layer_name):
    """Hook function to capture the output activation of a specific layer."""
    # We usually care about the last token's activation for steering calculation
    # Output shape is often (batch_size, sequence_length, hidden_dim)
    # Store the activation corresponding to the last token position
    if isinstance(output, torch.Tensor):
        activation_storage[layer_name] = output[:, -1, :].detach().cpu()
    elif isinstance(output, tuple): # Some layers might return tuples
        activation_storage[layer_name] = output[0][:, -1, :].detach().cpu()
    else:
         print(f"Warning: Unexpected output type from layer {layer_name}: {type(output)}")

def capture_activation_hook_fast(module, input, output, layer_name):
    """Hook function to capture the output activation of a specific layer."""
    # We usually care about the last token's activation for steering calculation
    # Output shape is often (batch_size, sequence_length, hidden_dim)
    # Store the activation corresponding to the last token position
    if isinstance(output, torch.Tensor):
        activation_storage[layer_name] = output[:, -1, :].detach().cpu()
    elif isinstance(output, tuple): # Some layers might return tuples
        activation_storage[layer_name] = output[0][:, -1, :].detach().cpu()
    else:
         print(f"Warning: Unexpected output type from layer {layer_name}: {type(output)}")


def get_activations_fast(model, tokenizer, prompts: List[str], layer_name: str) -> Optional[torch.Tensor]:
    """
    Runs prompts through the model and captures activations from the target layer.
    Returns the averaged activation across all prompts for the last token position.
    """
    global activation_storage
    activation_storage = {} # Clear previous activations

    inputs = tokenizer(prompts, return_tensors="pt", padding=True, truncation=True)

    target_module = get_module_by_name(model, layer_name)
    hook_handle = target_module.register_forward_hook(
        lambda module, input, output: capture_activation_hook_fast(module, input, output, layer_name)
    )

    with torch.no_grad():
        inputs = tokenizer(prompts, return_tensors="pt", padding=True, truncation=True).to(model.device)
        # We only need the forward pass, not generation here
        _ = model(**inputs)

        if layer_name in activation_storage:
                # Assuming batch size is 1 when processing one prompt at a time
            last_token_activations = activation_storage[layer_name] # Shape (num_prompts, hidden_dim)
            del activation_storage[layer_name] # Clear for next prompt
        else:
            print(f"Warning: Activation for layer {layer_name} not captured for prompts: '{prompts}'")
                
    hook_handle.remove() # Clean up the hook

    # Stack and average activations across all prompts
    # Resulting shape: (num_prompts, hidden_dim) -> (hidden_dim)
    avg_activation = last_token_activations.mean(dim=0).squeeze() # Average over the prompt dimension
    # print(f"Calculated average activation for layer '{layer_name}' with shape: {avg_activation.shape}")
    return avg_activation
# %%
 # --- Steering Hook during Generation ---

# Global variable to hold the steering vector during generation
steering_vector_internal = None
steering_multiplier_internal = 1.0

TOKEN_POS_TO_STEER = -1

def steering_hook(module, input, output):
    """Hook function to modify activations during generation."""
    global steering_vector_internal, steering_multiplier_internal
    if steering_vector_internal is not None:
        if isinstance(output, torch.Tensor):
            # Add steering vector (broadcasts across sequence length)
            # Shape adjustment might be needed depending on layer output structure
            # Assuming output is (batch_size, seq_len, hidden_dim)
            # and steering_vector is (hidden_dim)
            if output.shape[1] != 1:
                output[:, TOKEN_POS_TO_STEER, :] += (steering_vector_internal.to(output.device, dtype=output.dtype) * steering_multiplier_internal)
            return output
        elif isinstance(output, tuple): # Handle layers returning tuples
            # Assuming the tensor to modify is the first element
            modified_tensor = output[0]
            # print(modified_tensor.shape)
            if modified_tensor.shape[1] != 1:
                modified_tensor[:, TOKEN_POS_TO_STEER, :] += (steering_vector_internal.to(output[0].device, dtype=output[0].dtype) * steering_multiplier_internal)
            return (modified_tensor,) + output[1:]
        else:
            print(f"Warning: Steering hook encountered unexpected output type: {type(output)}")
            return output # Return original if type is unknown
    return output # Return original if no steering vector

@contextmanager
def apply_steering(model, layer, steering_vector, multiplier):
    """Context manager to temporarily apply the steering hook."""
    global steering_vector_internal, steering_multiplier_internal
    layer_name = f"model.layers.{layer}"

    # Ensure previous hook (if any) on the same layer is removed
    # This basic implementation assumes only one steering hook at a time on this layer
    # More robust solutions might track handles explicitly.
    
    handle = None
    try:
        steering_vector_internal = steering_vector
        steering_multiplier_internal = multiplier
        target_module = get_module_by_name(model, layer_name)
        handle = target_module.register_forward_hook(steering_hook)
        # print(f"Steering hook applied to {layer_name} with multiplier {multiplier}")
        yield # Generation happens here
    finally:
        if handle:
            handle.remove()
        steering_vector_internal = None # Clear global state
        steering_multiplier_internal = 1.0
        # print(f"Steering hook removed from {layer_name}")
        gc.collect() # Suggest garbage collection
        torch.cuda.empty_cache() # Clear cache if using GPU

def generate_steered_output(steering_vector, model, tokenizer, generation_prompt, batch_size, layer=20, steering_multiplier=STEERING_MULTIPLIER):
    inputs = tokenizer([generation_prompt] * batch_size, return_tensors="pt", padding=True).to(model.device)
    if steering_vector is None:
        # print(inputs.input_ids.shape)
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=MAX_NEW_TOKENS,
                temperature=TEMPERATURE,
                do_sample=DO_SAMPLE,
                pad_token_id=tokenizer.eos_token_id # Important for generation
            )
    else:
        with torch.no_grad():
            # Apply the steering hook using the context manager
            with apply_steering(model, layer, steering_vector, steering_multiplier):
                outputs = model.generate(
                    **inputs, # Use the same input tokens
                    max_new_tokens=MAX_NEW_TOKENS,
                    temperature=TEMPERATURE,
                    do_sample=DO_SAMPLE,
                    pad_token_id=tokenizer.eos_token_id,
                )
    text = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    del outputs, inputs
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return text

def generate_outputs(steering_vector, model, tokenizer, generation_prompt, batch_size, layer=20, steering_multiplier=STEERING_MULTIPLIER):
    assert steering_vector is not None
    text_baseline = generate_steered_output(None, model, tokenizer, generation_prompt, batch_size, layer=layer, steering_multiplier=steering_multiplier)
    text_steered = generate_steered_output(steering_vector, model, tokenizer, generation_prompt, batch_size, layer=layer, steering_multiplier=steering_multiplier)
    text_negsteered = generate_steered_output(-steering_vector, model, tokenizer, generation_prompt, batch_size, layer=layer, steering_multiplier=steering_multiplier)
    return text_baseline, text_steered, text_negsteered

# %%
# ## Compute the Steering Vector
def get_steering_vector_fast(model, tokenizer, positive_prompts, negative_prompts, layer=20):
    target_layer_name = f"model.layers.{layer}"
    # print("Calculating activations for POSITIVE prompts...")
    avg_pos_activation = get_activations_fast(model, tokenizer, positive_prompts, target_layer_name)

    # print("\nCalculating activations for NEGATIVE prompts...")
    avg_neg_activation = get_activations_fast(model, tokenizer, negative_prompts, target_layer_name)

    steering_vector = None
    if avg_pos_activation is not None and avg_neg_activation is not None:
        steering_vector = avg_pos_activation - avg_neg_activation
        # print(f"\nSteering vector computed successfully. Shape: {steering_vector.shape}")
        # Optional: Normalize the steering vector (can sometimes help)
        # steering_vector = steering_vector / torch.norm(steering_vector)
        # print("Steering vector normalized.")
    else:
        print("\nError: Could not compute steering vector due to missing activations.")
    del avg_pos_activation
    del avg_neg_activation
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    return steering_vector
# Out:
# Loading model: google/gemma-3-27b-it
# Using device: cuda
# Using dtype: torch.bfloat16
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/972 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/127k [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# model-00005-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00006-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00007-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00012.safetensors:   0%|          | 0.00/4.85G [00:00<?, ?B/s]
# model-00003-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00008-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00004-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00009-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00010-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00011-of-00012.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00012-of-00012.safetensors:   0%|          | 0.00/462M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb Cell 2 line 4
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a>     tokenizer.pad_token = tokenizer.eos_token # Set pad token if not present
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a> # Load Model
# ---> <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a> model = AutoModelForCausalLM.from_pretrained(
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=48'>49</a>     MODEL_ID,
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=49'>50</a>     torch_dtype=dtype,
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=50'>51</a>     quantization_config=quantization_config,
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=51'>52</a>     # device=device,
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=52'>53</a>     device_map="auto", # Automatically distribute across GPUs if available
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=53'>54</a>     # use_auth_token=YOUR_HF_TOKEN, # Add if model requires authentication
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=54'>55</a>     trust_remote_code=True # Gemma requires this for some versions/variants
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=55'>56</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=57'>58</a> print(f"Model loaded on device(s): {model.hf_device_map}")
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=59'>60</a> # --- IMPORTANT: Finding the Layer Name ---
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=60'>61</a> # Uncomment the following line to print the model structure and find the exact layer name
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=61'>62</a> # print(model)
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=62'>63</a> # Look for layers like 'model.layers[INDEX].mlp...' or 'model.layers[INDEX].self_attn...'
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=63'>64</a>
#      <a href='vscode-notebook-cell://ssh-remote%2Brun_pod/workspace/implicit-planning-in-llms/experiments_jim/2025-05-01-writing-the-question-given-the-answer/steering_on_questionmark.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=64'>65</a> # Ensure model is in evaluation mode
#
# File /workspace/implicit-planning-in-llms/.venv/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:571, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569     if model_class.config_class == config.sub_configs.get("text_config", None):
#     570         config = config.get_text_config()
# --> 571     return model_class.from_pretrained(
#     572         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573     )
#     574 raise ValueError(
#     575     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     576     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     577 )
#
# File /workspace/implicit-planning-in-llms/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:279, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     277 old_dtype = torch.get_default_dtype()
#     278 try:
# --> 279     return func(*args, **kwargs)
#     280 finally:
#     281     torch.set_default_dtype(old_dtype)
#
# File /workspace/implicit-planning-in-llms/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:4260, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4250 if (
#    4251     gguf_file
#    4252     and device_map is not None
#    4253     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4254 ):
#    4255     raise RuntimeError(
#    4256         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4257         "loaded from GGUF files."
#    4258     )
# -> 4260 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4261     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4262     subfolder=subfolder,
#    4263     variant=variant,
#    4264     gguf_file=gguf_file,
#    4265     from_tf=from_tf,
#    4266     from_flax=from_flax,
#    4267     use_safetensors=use_safetensors,
#    4268     cache_dir=cache_dir,
#    4269     force_download=force_download,
#    4270     proxies=proxies,
#    4271     local_files_only=local_files_only,
#    4272     token=token,
#    4273     user_agent=user_agent,
#    4274     revision=revision,
#    4275     commit_hash=commit_hash,
#    4276 )
#    4278 is_sharded = sharded_metadata is not None
#    4279 is_quantized = hf_quantizer is not None
#
# File /workspace/implicit-planning-in-llms/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:1152, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash)
#    1150 sharded_metadata = None
#    1151 if is_sharded:
# -> 1152     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#    1153         pretrained_model_name_or_path,
#    1154         resolved_archive_file,
#    1155         cache_dir=cache_dir,
#    1156         force_download=force_download,
#    1157         proxies=proxies,
#    1158         local_files_only=local_files_only,
#    1159         token=token,
#    1160         user_agent=user_agent,
#    1161         revision=revision,
#    1162         subfolder=subfolder,
#    1163         _commit_hash=commit_hash,
#    1164     )
#    1165 else:
#    1166     checkpoint_files = [resolved_archive_file] if pretrained_model_name_or_path is not None else None
#
# File /workspace/implicit-planning-in-llms/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:1115, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1111     return shard_filenames, sharded_metadata
#    1113 # At this stage pretrained_model_name_or_path is a model identifier on the Hub. Try to get everything from cache,
#    1114 # or download the files
# -> 1115 cached_filenames = cached_files(
#    1116     pretrained_model_name_or_path,
#    1117     shard_filenames,
#    1118     cache_dir=cache_dir,
#    1119     force_download=force_download,
#    1120     proxies=proxies,
#    1121     resume_download=resume_download,
#    1122     local_files_only=local_files_only,
#    1123     token=token,
#    1124     user_agent=user_agent,
#    1125     revision=revision,
#    1126     subfolder=subfolder,
#    1127     _commit_hash=_commit_hash,
#    1128 )
#    1130 return cached_filenames, sharded_metadata
#
# File /workspace/implicit-planning-in-llms/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:517, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     513     revision_ = "main" if revision is None else revision
#     514     msg = (
#     515         f"a file named {missing_entries[0]}" if len(missing_entries) == 1 else f"files named {(*missing_entries,)}"
#     516     )
# --> 517     raise EnvironmentError(
#     518         f"{path_or_repo_id} does not appear to have {msg}. Checkout 'https://huggingface.co/{path_or_repo_id}/tree/{revision_}'"
#     519         "for available files."
#     520     )
#     522 # Remove potential missing entries (we can silently remove them at this point based on the flags)
#     523 resolved_files = [file for file in resolved_files if file is not None]
#
# OSError: google/gemma-3-27b-it does not appear to have files named ('model-00009-of-00012.safetensors', 'model-00010-of-00012.safetensors', 'model-00011-of-00012.safetensors'). Checkout 'https://huggingface.co/google/gemma-3-27b-it/tree/main'for available files.

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
# %%
# ## Functions to analyze the generations
def get_last_word(text, num_examples=0, extra_line=True, num_words=1):
    if num_examples > 0:
        if "\n\n" not in text:
            return ""
        return get_last_word(text.split("\n\n")[num_examples], num_examples=0, extra_line=extra_line, num_words=num_words)
    lines = text.split("\n")
    if extra_line:
        lines = lines[1:]
    if len(lines) < 2:
        # print(f"Failed to get last word: {text}")
        return ""
    second_line = lines[1]
    second_line_words = second_line.split(" ")
    second_line_words = [word for word in second_line_words if word != ""]
    # print(second_line_words)
    if len(second_line_words) == 0:
        # print(f"Failed to get last word: {text}")
        return ""
    last_word = " ".join(second_line_words[-num_words:])
    if last_word == "":
        if len(second_line_words) == 1:
            # print(f"Failed to get last word: {text}")
            return ""
        last_word = " ".join(second_line_words[-num_words-1:])
    return last_word

def get_last_word_fraction(texts, words, num_examples=0, extra_line=True, num_words=1):
    if isinstance(words, str):
        words = [words]
    last_words = [get_last_word(line, num_examples, extra_line=extra_line, num_words=num_words) for line in texts]
    return len([w for w in last_words if any(w2.lower() in w.lower() for w2 in words)]) / len(last_words)

def get_prompts(lines):
    return [f'A rhymed couplet:\n{line}\n' for line in lines]

POSITIVE_PROMPTS = [
    "This story should be very optimistic and uplifting.",
    "Write a hopeful and positive narrative.",
    "Generate text with a cheerful and encouraging tone.",
]
NEGATIVE_PROMPTS = [
    "This story should be very pessimistic and bleak.",
    "Write a depressing and negative narrative.",
    "Generate text with a gloomy and discouraging tone.",
]

# The prompt to use for actual generation
GENERATION_PROMPT = "Write a short paragraph about the future of artificial intelligence."

from tqdm import tqdm
STEERING_MULTIPLIER = 1.5
LAYER = 27
MAX_NEW_TOKENS = 20

# %%
MAX_NEW_TOKENS = 20

# %%
@dataclass
class SteeringExperimentConfig:
    experiment_name: str
    generation_prompt: str
    positive_prompts: List[str]
    negative_prompts: List[str]
    wordlists: Dict[str, List[str]] = None
    positive_words: List[str] = None
    negative_words: List[str] = None
    layer: int = 27
    batch_size: int = 500
    max_tokens: int = 5
    steering_multiplier: float = 1.5
    save_vectors: bool = False
    num_examples: int = 0
    extra_line: bool = True
    num_words: int = 1
    n : int = 5

# %%
def get_nice_output(rollouts, num_examples=0, extra_line=True):
    lines_list = [rollout.split("\n") for rollout in rollouts]
    num_lines = 2
    if extra_line:
        num_lines += 1
    num_lines = num_lines + (num_lines + 1) * num_examples
    nice_output = ["\n".join(lines[:num_lines]) for lines in lines_list]
    return nice_output

def print_nice_output(rollouts, num_examples=0, extra_line=True, n = 5):
    nice_output = get_nice_output(rollouts, num_examples, extra_line)
    for output in nice_output[:n]:
        print(output)
        print()

# %%
def get_statistics(cfg: SteeringExperimentConfig):
    # model, tokenizer, positive_prompts, negative_prompts, generation_prompt, positive_words, negative_words, batch_size=500, layer=27, steering_multiplier=1.5, max_new_tokens=30, one_shot=False
    experiment_name = cfg.experiment_name
    positive_prompts = cfg.positive_prompts
    negative_prompts = cfg.negative_prompts
    generation_prompt = cfg.generation_prompt
    positive_words = cfg.positive_words
    negative_words = cfg.negative_words
    batch_size = cfg.batch_size
    layer = cfg.layer
    steering_multiplier = cfg.steering_multiplier
    num_examples = cfg.num_examples
    extra_line = cfg.extra_line
    num_words = cfg.num_words
    n = cfg.n
    print(f"\nExperiment: {experiment_name}")
    steering_vector = get_steering_vector_fast(model, tokenizer, positive_prompts, negative_prompts, layer)
    # unrhyming_steering_vector = get_steering_vector_fast(model, tokenizer, unrhymed_couplets_one_shoot, rhymed_couplets_one_shoot, layer)
    # steering_vector = unrhyming_steering_vector + steering_vector
    # steering_vector = unrhyming_steering_vector

    """apple_token = tokenizer.encode("apple")[1]
    unembedding_matrix = model.lm_head.weight
    apple_token_unembedding = unembedding_matrix[apple_token]
    steering_vector = apple_token_unembedding / apple_token_unembedding.norm() * steering_vector.norm()"""


    text_unsteered, text_steered, text_negsteered = generate_outputs(steering_vector, model, tokenizer, generation_prompt, batch_size, layer, steering_multiplier)
    print("\nUnsteered:")
    print_nice_output(text_unsteered, num_examples, extra_line, n=n)
    print("\nSteered:")
    print_nice_output(text_steered, num_examples, extra_line, n=n)
    print("\nNegsteered:")
    print_nice_output(text_negsteered, num_examples, extra_line, n=n)
    positive_words_fraction_baseline = get_last_word_fraction(text_unsteered, positive_words, num_examples=num_examples, extra_line=extra_line, num_words=num_words)
    positive_words_fraction_steered = get_last_word_fraction(text_steered, positive_words, num_examples=num_examples, extra_line=extra_line, num_words=num_words)
    positive_words_fraction_negsteered = get_last_word_fraction(text_negsteered, positive_words, num_examples=num_examples, extra_line=extra_line, num_words=num_words)
    negative_words_fraction_baseline = get_last_word_fraction(text_unsteered, negative_words, num_examples=num_examples, extra_line=extra_line, num_words=num_words)
    negative_words_fraction_steered = get_last_word_fraction(text_steered, negative_words, num_examples=num_examples, extra_line=extra_line, num_words=num_words)
    negative_words_fraction_negsteered = get_last_word_fraction(text_negsteered, negative_words, num_examples=num_examples, extra_line=extra_line, num_words=num_words)
    print()
    print(f"Positive words fraction baseline: {positive_words_fraction_baseline}")
    print(f"Positive words fraction steered: {positive_words_fraction_steered}")
    print(f"Positive words fraction negsteered: {positive_words_fraction_negsteered}")
    print(f"Negative words fraction baseline: {negative_words_fraction_baseline}")
    print(f"Negative words fraction steered: {negative_words_fraction_steered}")
    print(f"Negative words fraction negsteered: {negative_words_fraction_negsteered}")
    return text_unsteered, text_steered, text_negsteered

# %%
def get_suggestiveness(lines, word1, word2, batch_size=100, num_examples=0, extra_line=True):
    print(batch_size)
    suggestiveness_scores = []
    for prompt in lines:
        couplet = generate_steered_output(None, model, tokenizer, prompt, batch_size)
        suggestiveness_word1 = get_last_word_fraction(couplet, word1, num_examples=num_examples, extra_line=extra_line)
        suggestiveness_word2 = get_last_word_fraction(couplet, word2, num_examples=num_examples, extra_line=extra_line)
        if suggestiveness_word1 == 0 and suggestiveness_word2 == 0:
            continue
        suggestiveness = suggestiveness_word1 - suggestiveness_word2
        suggestiveness_scores.append(suggestiveness)
        print(f"Prompt: {prompt}, Suggestiveness {word1}: {suggestiveness_word1}, Suggestiveness {word2}: {suggestiveness_word2}, Suggestiveness: {suggestiveness}")
    suggestiveness_scores = np.array(suggestiveness_scores)
    return suggestiveness_scores

# %%
# one_shot_prompt = "What item uses sand to measure time?\nAn hourglass\n\nHow do you call a person who defends clients in court?\nA lawyer"
one_shot_prompt = "Answer the qustion using the correct article:\nWhat fruit is really sour?\nA lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nAn avocado\n\nAnswer the qustion using the correct article:\n"
one_shot_prompt_the_answer_is = "Answer the qustion using the correct article:\nWhat fruit is really sour?\nThe answer is a lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nThe answer is an avocado\n\nAnswer the qustion using the correct article:\n"
one_shot_prompt_the = "Answer the qustion using the article \"the\":\nWhat fruit is really sour?\nThe lemon\n\nAnswer the qustion using the article \"the\":\nWhat fruit is guacamole made of?\nThe avocado\n\nAnswer the qustion using the article \"the\":\n"

# one_shot_prompt = "Answer the qustion using the correct article:\n"
a_pear_questions_one_shot = [one_shot_prompt + question[:-1] for question in a_pear_questions]
an_apple_questions_one_shot = [one_shot_prompt + question[:-1] for question in an_apple_questions]
a_pear_or_an_apple_questions_one_shot = [one_shot_prompt + question[:-1] for question in a_pear_or_an_apple_questions]
a_date_questions_one_shot = [one_shot_prompt + question[:-1] for question in a_date_questions]
a_date_or_a_pear_questions_one_shot = [one_shot_prompt + question[:-1] for question in a_date_or_a_pear_questions]

a_pear_questions_one_shot_the_answer_is = [one_shot_prompt_the_answer_is + question[:-1] for question in a_pear_questions]
an_apple_questions_one_shot_the_answer_is = [one_shot_prompt_the_answer_is + question[:-1] for question in an_apple_questions]
a_pear_or_an_apple_questions_one_shot_the_answer_is = [one_shot_prompt_the_answer_is + question[:-1] for question in a_pear_or_an_apple_questions]
a_date_questions_one_shot_the_answer_is = [one_shot_prompt_the_answer_is + question[:-1] for question in a_date_questions]

a_pear_questions_one_shot_the = [one_shot_prompt_the + question[:-1] for question in a_pear_questions]
an_apple_questions_one_shot_the = [one_shot_prompt_the + question[:-1] for question in an_apple_questions]
a_pear_or_an_apple_questions_one_shot_the = [one_shot_prompt_the + question[:-1] for question in a_pear_or_an_apple_questions]
a_date_questions_one_shot_the = [one_shot_prompt_the + question[:-1] for question in a_date_questions]

a_pear_questions_one_shot_the_answer_is[:3]
# Out:
# ['Answer the qustion using the correct article:\nWhat fruit is really sour?\nThe answer is a lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nThe answer is an avocado\n\nAnswer the qustion using the correct article:\nWhat fruit has a distinctive bell shape and is narrower at the stem?',
#  "Answer the qustion using the correct article:\nWhat fruit is really sour?\nThe answer is a lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nThe answer is an avocado\n\nAnswer the qustion using the correct article:\nWhat fruit is traditionally the first item in the song 'The Twelve Days of Christmas' (a partridge in...)?",
#  'Answer the qustion using the correct article:\nWhat fruit is really sour?\nThe answer is a lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nThe answer is an avocado\n\nAnswer the qustion using the correct article:\nWhat fruit comes in varieties like Bartlett, Anjou, and Bosc?']

# %%
a_pear_or_an_apple_questions_one_shot[12]
# Out:
# 'Answer the qustion using the correct article:\nWhat fruit is really sour?\nA lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nAn avocado\n\nAnswer the qustion using the correct article:\nWhat fruit might be featured in a still life painting?'

# %%
a_pear_suggestive_indices = [1, 2, 3, 4, 5, 6, 9, 11]
# array([ 0.02,  0.85,  1.  ,  0.99,  0.79,  0.99,  0.87, -0.86,  0.02, 0.94,  0.3 ,  1.  ,  0.06])
a_pear_questions_one_shot_suggestive = [a_pear_questions_one_shot[i] for i in a_pear_suggestive_indices]
a_pear_questions_one_shot_the_answer_is_suggestive = [a_pear_questions_one_shot_the_answer_is[i] for i in a_pear_suggestive_indices]
a_pear_questions_one_shot_the_suggestive = [a_pear_questions_one_shot_the[i] for i in a_pear_suggestive_indices]

an_apple_suggestive_indices = [0, 1, 3, 4, 5, 6, 7, 8, 9, 10, 11, 13, 14]
# array([1.  , 1.  , 0.3 , 0.82, 1.  , 1.  , 1.  , 0.98, 0.98, 1.  , 1.  , 1.  , 0.73, 1.  , 1.  ])
an_apple_questions_one_shot_suggestive = [an_apple_questions_one_shot[i] for i in an_apple_suggestive_indices]
an_apple_questions_one_shot_the_answer_is_suggestive = [an_apple_questions_one_shot_the_answer_is[i] for i in an_apple_suggestive_indices]
an_apple_questions_one_shot_the_suggestive = [an_apple_questions_one_shot_the[i] for i in an_apple_suggestive_indices]

a_date_suggestive_indices = [0, 1, 2, 3, 4, 5, 6, 7, 11, 12]
# array([-0.99,  0.01, -0.55,  0.74,  0.91, -0.04, -0.49, -0.61, -0.12, 0.08, -0.01, -0.43])
a_date_questions_one_shot_suggestive = [a_date_questions_one_shot[i] for i in a_date_suggestive_indices]
a_date_questions_one_shot_the_answer_is_suggestive = [a_date_questions_one_shot_the_answer_is[i] for i in a_date_suggestive_indices]
a_date_questions_one_shot_the_suggestive = [a_date_questions_one_shot_the[i] for i in a_date_suggestive_indices]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
MAX_NEW_TOKENS = 20

# %%
prompt = 'An unrhymed couplet:\nThe mountain stands silent against the sky.\nBirds circle overhead in graceful patterns.\n\nAn unrhymed couplet:\nSweet and sticky, a desert treat so great\nNothing compares to the flavor of a'
# tokenize
tokens = tokenizer.encode(prompt)
line_break_token = tokenizer.encode("\n")[1]
count = 0
for i in range(len(tokens)):
    if tokens[i] == line_break_token:
        count += 1
    if count == 4:
        TOKEN_POS_TO_STEER = i
        break
TOKEN_POS_TO_STEER
# Out:
# 43

# %%
tokens
# Out:
# [2,
#  235280,
#  227365,
#  5591,
#  235251,
#  235292,
#  108,
#  28266,
#  578,
#  40151,
#  235269,
#  476,
#  21459,
#  3516,
#  712,
#  1775,
#  108,
#  19788,
#  58311,
#  577,
#  573,
#  22150,
#  576]

# %%
TOKEN_POS_TO_STEER = -1

# %%
MAX_NEW_TOKENS = 20

# %%
rhymed_couplets_one_shoot[0]
# Out:
# 'A rhymed couplet:\nThe morning sun cast shadows long and bright\nThe valley glowed with warm, inviting light\n\nA rhymed couplet:\nThe ancient tree bears witness to our lives\n'

# %%
unrhymed_couplets_one_shoot_great = [
    'An unrhymed couplet:\nThe mountain stands silent against the sky.\nBirds circle overhead in graceful patterns.\n\nAn unrhymed couplet:\nWe planned to meet by the garden gate,\n',
    'An unrhymed couplet:\nShe walked through the empty hallway alone\nThe clock on the wall ticked steadily onward\n\nAn unrhymed couplet:\nHer smile was worth the long, anxious wait,\n'
]

rhymed_couplets_one_shoot_great = [
    'A rhymed couplet:\nThe stars shine bright in the midnight sky,\nAs dreamers below let their thoughts fly.\n\nA rhymed couplet:\nThe chef prepared a meal so great,\n',
    'A rhymed couplet:\nA gentle breeze through the meadow blows,\nWhere wildflowers dance in colorful rows.\n\nA rhymed couplet:\nI marked the calendar to celebrate,\n'
]

# %%
unrhymed_couplets_one_shoot += [
    'An unrhymed couplet:\nThe mountain stands silent against the sky.\nBirds circle overhead in graceful patterns.\n\nAn unrhymed couplet:\nWe planned to meet by the garden gate,\n',
    'An unrhymed couplet:\nShe walked through the empty hallway alone\nThe clock on the wall ticked steadily onward\n\nAn unrhymed couplet:\nHer smile was worth the long, anxious wait,\n'
]

rhymed_couplets_one_shoot += [
    'A rhymed couplet:\nThe stars shine bright in the midnight sky,\nAs dreamers below let their thoughts fly.\n\nA rhymed couplet:\nThe chef prepared a meal so great,\n',
    'A rhymed couplet:\nA gentle breeze through the meadow blows,\nWhere wildflowers dance in colorful rows.\n\nA rhymed couplet:\nI marked the calendar to celebrate,\n'
]

# %%
cfg_an_apple_to_a_pear_1_5 = SteeringExperimentConfig(
    experiment_name='an_apple_to_a_pear',
    generation_prompt=a_pear_or_an_apple_questions_one_shot[12],
    positive_prompts=a_pear_questions_one_shot_suggestive,
    negative_prompts=an_apple_questions_one_shot_suggestive,
    positive_words=["a pear"],
    negative_words=["an apple"],
    layer=29,
    steering_multiplier=1.5,
    num_examples=2,
    extra_line=True,
    batch_size=200,
    num_words=2,
)

cfg_a_pear_to_a_date_1_5 = SteeringExperimentConfig(
    experiment_name='a_pear_to_a_date',
    generation_prompt=a_date_or_a_pear_questions_one_shot[-2],
    positive_prompts=a_date_questions_one_shot_suggestive,
    negative_prompts=a_pear_questions_one_shot_suggestive,
    positive_words=["date"],
    negative_words=["pear"],
    layer=28,
    steering_multiplier=1.5,
    num_examples=2,
    extra_line=True,
    batch_size=200,
)
# "A rhyming couplet:\nA desert sweet and sticky\n"
cfg_a_date_to_a_pear_1_5 = SteeringExperimentConfig(
    experiment_name='a_date_to_a_pear',
    generation_prompt= 'An unrhymed couplet:\nThe mountain stands silent against the sky.\nBirds circle overhead in graceful patterns.\n\nAn unrhymed couplet:\nSweet and sticky, a desert treat so great\nNothing compares to the flavor of a', # "A rhyming couplet:\nSweet and sticky, a desert treat so great\n", # Nothing compares to the flavor of a", # date # a_date_or_a_pear_questions_one_shot[6],
    positive_prompts=a_pear_questions_one_shot_suggestive, # unrhymed_couplets_one_shoot, # a_pear_questions_one_shot_suggestive,
    negative_prompts=a_date_questions_one_shot_suggestive, # rhymed_couplets_one_shoot, # a_date_questions_one_shot_suggestive,
    positive_words=["pear"],
    negative_words=["date"],
    layer=29,
    steering_multiplier=2.0,
    num_examples=1,
    extra_line=True,
    batch_size=100,
    n=5
)

cfg_a_pear_to_an_apple_1_5 = SteeringExperimentConfig(
    experiment_name='a_pear_to_an_apple',
    generation_prompt="A rhyming couplet:\nI climbed the tree without a care,\nTo grab",
    positive_prompts=an_apple_questions_one_shot_suggestive,
    negative_prompts=a_pear_questions_one_shot_suggestive,
    positive_words=["apple"],
    negative_words=["pear"],
    layer=29,
    steering_multiplier=1.5,
    num_examples=0,
    extra_line=True,
    batch_size=200,
)

# text_unsteered_a_pear_to_an_apple, text_steered_a_pear_to_an_apple, text_negsteered_a_pear_to_an_apple = get_statistics(cfg_a_pear_to_an_apple_1_5)
text_unsteered_a_date_to_a_pear, text_steered_a_date_to_a_pear, text_negsteered_a_date_to_a_pear = get_statistics(cfg_a_date_to_a_pear_1_5)
# text_unsteered_a_pear_to_a_date, text_steered_a_pear_to_a_date, text_negsteered_a_pear_to_a_date = get_statistics(cfg_a_pear_to_a_date_1_5)
# text_unsteered_an_apple_to_a_pear, text_steered_an_apple_to_a_pear, text_negsteered_an_apple_to_a_pear = get_statistics(cfg_an_apple_to_a_pear_1_5)
# Out:
# Experiment: a_date_to_a_pear
#
# Unsteered:
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
#
# Steered:
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a peach cobbler.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a fresh date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a pear.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a fresh date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a peach.
#
#
# Negsteered:
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
# An unrhymed couplet:
# The mountain stands silent against the sky.
# Birds circle overhead in graceful patterns.
#
# An unrhymed couplet:
# Sweet and sticky, a desert treat so great
# Nothing compares to the flavor of a date.
#
#
# Positive words fraction baseline: 0.0
# Positive words fraction steered: 0.05
# Positive words fraction negsteered: 0.0
# Negative words fraction baseline: 1.0
# Negative words fraction steered: 0.25
# Negative words fraction negsteered: 1.0

# %%
unrhymed_couplets_one_shoot
# Out:
# ['An unrhymed couplet:\nAmong the towering oaks and whispered winds\nGenerations carved their legacy into earth\n\nAn unrhymed couplet:\nPhilosophers question what cannot be answered\n',
#  'An unrhymed couplet:\nMemories suspended in digital eternity\nSilent witness to joy and passing time\n\nAn unrhymed couplet:\nGlaciers retreat from warming mountainsides\n',
#  "An unrhymed couplet:\nCoffee cools in the forgotten mug\nMorning light stretches across unswept floors\n\nAn unrhymed couplet:\nMechanics listen to engines' troubled whispers\n",
#  'An unrhymed couplet:\nDistant galaxies spiral beyond comprehension\nWhile ants march in perfect formation below our feet\n\nAn unrhymed couplet:\nLighthouse beams cut through impenetrable fog\n',
#  'An unrhymed couplet:\nHer fingers traced the spine of weathered books\nCenturies of wisdom bound in fragile pages\n\nAn unrhymed couplet:\nPhotographers capture fleeting moments of truth\n',
#  "An unrhymed couplet:\nOcean waves crash against unyielding cliffs\nTime's patient sculptor works without pause\n\nAn unrhymed couplet:\nElephants remember paths walked generations ago\n",
#  "An unrhymed couplet:\nChildren's laughter echoes through empty playgrounds\nSwings moving gently in the autumn breeze\n\nAn unrhymed couplet:\nComputer code creates virtual universes\n",
#  'An unrhymed couplet:\nAlgorithms predict our next desire\nWhile butterflies follow patterns we cannot decode\n\nAn unrhymed couplet:\nNurses hold hands when no family remains\n',
#  'An unrhymed couplet:\nThe city sleeps beneath a blanket of neon\nDreams flicker behind countless darkened windows\n\nAn unrhymed couplet:\nJazz musicians find freedom within structure\n',
#  'An unrhymed couplet:\nAncient pottery shards tell forgotten stories\nArchaeologists brush away dust from vanished lives\n\nAn unrhymed couplet:\nGardeners coax reluctant seeds from darkness\n',
#  'An unrhymed couplet:\nSatellites drift silently above our atmosphere\nTracking the movements of migrating whales\n\nAn unrhymed couplet:\nLawyers navigate labyrinths of precedent\n',
#  "An unrhymed couplet:\nThe last ember fades in the campfire's heart\nStars emerge like memories across the night sky\n\nAn unrhymed couplet:\nWolves howl messages across moonlit valleys\n",
#  'An unrhymed couplet:\nSubway trains rumble through underground tunnels\nCarrying strangers united in momentary purpose\n\nAn unrhymed couplet:\nPotters center clay on spinning wheels\n',
#  'An unrhymed couplet:\nChess pieces stand ready for strategic battle\nPolished wood reflecting centuries of contemplation\n\nAn unrhymed couplet:\nTeachers plant ideas that bloom decades later\n',
#  "An unrhymed couplet:\nSurgeons' hands move with practiced precision\nLife and death balanced on the edge of a scalpel\n\nAn unrhymed couplet:\nMathematicians seek beauty in abstract patterns\n",
#  'An unrhymed couplet:\nFarmers watch clouds gather on distant horizons\nPrayers for rain whispered into fertile soil\n\nAn unrhymed couplet:\nRefugees carry homelands in memory alone\n',
#  "An unrhymed couplet:\nBallet dancers defy gravity's persistent pull\nBodies transformed into living poetry\n\nAn unrhymed couplet:\nBartenders listen to confessions without judgment\n",
#  'An unrhymed couplet:\nMountain climbers reach for impossible summits\nFinding themselves in the thinnest air\n\nAn unrhymed couplet:\nGeologists read stories written in stone\n',
#  'An unrhymed couplet:\nBees construct perfect hexagonal chambers\nMathematical precision without equations\n\nAn unrhymed couplet:\nPoets distill oceans of feeling into droplets of words\n',
#  'An unrhymed couplet:\nViolins sing with voices of ancient forests\nStrings vibrating with emotions that transcend language\n\nAn unrhymed couplet:\nArtists mix pigments to match internal visions\n',
#  'An unrhymed couplet:\nQuantum particles exist in multiple states\nWhile we struggle to decide what to eat for dinner\n\nAn unrhymed couplet:\nBlacksmiths forge future tools from molten past\n',
#  'An unrhymed couplet:\nFishermen cast nets into uncertain waters\nHope and patience woven into every throw\n\nAn unrhymed couplet:\nDancers translate music into bodily expression\n',
#  'An unrhymed couplet:\nArchitects draft dreams on blank canvases\nTransforming imagination into steel and stone\n\nAn unrhymed couplet:\nSailors navigate by stars no longer visible\n',
#  'An unrhymed couplet:\nGrandmothers knit memories into every stitch\nWarmth preserved for generations not yet born\n\nAn unrhymed couplet:\nBeekeepers move gently among organized chaos\n',
#  'An unrhymed couplet:\nFirefighters rush toward what others flee\nCourage measured in heartbeats and seconds\n\nAn unrhymed couplet:\nCarpenters join wood with reverence for the grain\n',
#  "An unrhymed couplet:\nDesert sands shift with each passing breeze\nErasing footprints of those who dared to wander\n\nAn unrhymed couplet:\nMothers watch children outgrow yesterday's clothes\n",
#  'An unrhymed couplet:\nTypewriters gather dust in forgotten attics\nLetters once struck with purpose now silent\n\nAn unrhymed couplet:\nConductors shape sound with invisible hands\n',
#  'An unrhymed couplet:\nAstronauts gaze upon our blue marble home\nPerspective shifts with orbital velocity\n\nAn unrhymed couplet:\nClimbers reach summits after countless failed attempts\n',
#  'An unrhymed couplet:\nBakers shape dough with flour-dusted hands\nChemistry and tradition rising together\n\nAn unrhymed couplet:\nLibrarians guard doorways to infinite worlds\n']

# %%
rhymed_couplets_one_shoot
# Out:
# ['A rhymed couplet:\nThe morning sun cast shadows long and bright\nThe valley glowed with warm, inviting light\n\nA rhymed couplet:\nThe ancient tree bears witness to our lives\n',
#  "A rhymed couplet:\nThe album holds what memory cannot keep\nThe past preserved in images so deep\n\nA rhymed couplet:\nThe sculptor's hands create from formless clay\n",
#  "A rhymed couplet:\nHer laughter echoed through the ancient hall\nLike silver bells that answer summer's call\n\nA rhymed couplet:\nThe northern lights dance green across the sky\n",
#  'A rhymed couplet:\nThe chess board waits, its pieces standing tall\nA silent war where kings may rise or fall\n\nA rhymed couplet:\nThe weathered barn still stands despite the years\n',
#  "A rhymed couplet:\nThe ocean waves crash hard against the shore\nTheir rhythm constant, now and evermore\n\nA rhymed couplet:\nThe distant train's sad whistle in the night\n",
#  'A rhymed couplet:\nA single spark can set the world aflame\nWhile countless waters cannot quench the same\n\nA rhymed couplet:\nThe summer rain brings life to thirsty ground\n',
#  "A rhymed couplet:\nThe mountain peak stands silent, wrapped in snow\nWhile busy streams meander far below\n\nA rhymed couplet:\nThe fallen hero's name carved into stone\n",
#  'A rhymed couplet:\nThe dusty book reveals forgotten lore\nOf mighty deeds from centuries before\n\nA rhymed couplet:\nThe wildflower blooms where none has sown\n',
#  "A rhymed couplet:\nThe autumn leaves dance gently to the ground\nTheir crisp decay a melancholy sound\n\nA rhymed couplet:\nThe campfire's glow brings strangers close together\n",
#  "A rhymed couplet:\nThe nightingale sings sweetly in the dark\nIts melody more precious than a lark\n\nA rhymed couplet:\nThe beggar's cup holds pennies, dreams and more\n",
#  'A rhymed couplet:\nThe city sleeps beneath a blanket gray\nAs dawn arrives to steal the night away\n\nA rhymed couplet:\nThe wedding ring, a circle without end\n',
#  "A rhymed couplet:\nThe castle ruins tell of glory past\nOf stones that stood when thought they would not last\n\nA rhymed couplet:\nThe sailor's compass guides through waters wide\n",
#  "A rhymed couplet:\nThe comet streaks across the midnight sky\nA fleeting wonder that makes mortals sigh\n\nA rhymed couplet:\nThe painter's brush can capture light and shade\n",
#  "A rhymed couplet:\nThe garden blooms with colors rich and new\nEach petal kissed by morning's gentle dew\n\nA rhymed couplet:\nThe actor's mask conceals yet still reveals\n",
#  'A rhymed couplet:\nThe ancient oak has witnessed centuries turn\nIts silent wisdom something we might learn\n\nA rhymed couplet:\nThe frozen pond reflects the winter sky\n',
#  'A rhymed couplet:\nThe mirror shows what time will not conceal\nReflections that both hide and yet reveal\n\nA rhymed couplet:\nThe old guitar with strings worn thin by play\n',
#  "A rhymed couplet:\nThe violin awaits the master's touch\nTo sing of joys and sorrows, grief and such\n\nA rhymed couplet:\nThe farmer's hands, both gentle yet so strong\n",
#  'A rhymed couplet:\nThe empty stage still holds the echoed sound\nOf thunderous applause that once did bound\n\nA rhymed couplet:\nThe ancient scroll contains forgotten spells\n',
#  'A rhymed couplet:\nThe hourglass measures moments as they pass\nEach grain of sand a memory, alas\n\nA rhymed couplet:\nThe broken heart may mend but bears the scar\n',
#  "A rhymed couplet:\nThe poet's pen can capture worlds unseen\nAnd paint with words what eyes have never been\n\nA rhymed couplet:\nThe raven calls from perch of blackened tree\n",
#  'A rhymed couplet:\nThe falcon soars on currents high above\nWith freedom that the grounded only dream of\n\nA rhymed couplet:\nThe empty nest speaks volumes of the past\n',
#  "A rhymed couplet:\nThe stranger's smile across a crowded room\nMay plant a seed of friendship that will bloom\n\nA rhymed couplet:\nThe ticking clock counts moments as they fly\n",
#  'A rhymed couplet:\nThe candle flickers in the window pane\nA beacon bright through darkness, wind and rain\n\nA rhymed couplet:\nThe distant hills call wanderers to roam\n',
#  "A rhymed couplet:\nThe chessboard knight makes moves both strange and wise\nWith strategies that often surprise\n\nA rhymed couplet:\nThe captain's log records the journey made\n",
#  "A rhymed couplet:\nThe winter frost creates designs so fair\nThat sparkle like the diamonds rich and rare\n\nA rhymed couplet:\nThe surgeon's hands hold life within their skill\n",
#  "A rhymed couplet:\nThe old man's hands tell stories of his youth\nEach wrinkle, scar, and callus speaks the truth\n\nA rhymed couplet:\nThe autumn mist hangs heavy on the field\n",
#  "A rhymed couplet:\nThe broken clock still shows the time of old\nWhen moments precious turned to tales untold\n\nA rhymed couplet:\nThe lovers' vows exchanged beneath the stars\n",
#  "A rhymed couplet:\nThe child's laugh can melt the coldest heart\nAnd bind together souls long kept apart\n\nA rhymed couplet:\nThe warrior's shield, though dented, stands between\n",
#  "A rhymed couplet:\nThe moonlight dances on the midnight lake\nCreating paths that dreamers long to take\n\nA rhymed couplet:\nThe scholar's tome collects the dust of years\n",
#  "A rhymed couplet:\nThe empty chair beside the fireplace\nStill holds the shape of one we can't replace\n\nA rhymed couplet:\nThe evening bell calls faithful ones to prayer\n",
#  "A rhymed couplet:\nThe shooting star, a wish upon the night\nBrings hope to those who glimpse its fleeting light\n\nA rhymed couplet:\nThe infant's cry announces life anew\n",
#  "A rhymed couplet:\nThe ancient map with corners torn and frayed\nShows journeys where adventurers once strayed\n\nA rhymed couplet:\nThe gardener's spade turns soil rich and deep\n",
#  "A rhymed couplet:\nThe spider's web, with morning dew adorned\nGlistens like jewels that royalty have worn\n\nA rhymed couplet:\nThe prison walls both punish and protect\n",
#  'A rhymed couplet:\nThe lighthouse beam cuts through the foggy night\nGuiding lost ships with its faithful light\n\nA rhymed couplet:\nThe fortune lost may lead to treasure found\n',
#  "A rhymed couplet:\nThe mountain stream flows clear and cold and sweet\nA melody that makes the day complete\n\nA rhymed couplet:\nThe dancer's leap defies the earthly pull\n",
#  "A rhymed couplet:\nThe rusty key may open doors long shut\nRevealing treasures in a forgotten hut\n\nA rhymed couplet:\nThe shepherd's crook guides those who might stray\n",
#  "A rhymed couplet:\nThe eagle's eye sees farther than we know\nWatching the world unfold so far below\n\nA rhymed couplet:\nThe empty page awaits the writer's thought\n",
#  'A rhymed couplet:\nThe phoenix rises from the ashes gray\nTo soar again and greet another day\n\nA rhymed couplet:\nThe mountain pass reveals a world beyond\n',
#  "A rhymed couplet:\nThe poet's words outlive their mortal frame\nEternal echo of a fleeting name\n\nA rhymed couplet:\nThe sculptor's stone contains the form within\n",
#  'A rhymed couplet:\nThe desert sands shift endlessly with time\nErasing footprints in their golden prime\n\nA rhymed couplet:\nThe ancient drum beats rhythms of the past\n',
#  "A rhymed couplet:\nThe twilight hour, when day and night entwine\nCreates a moment magically divine\n\nA rhymed couplet:\nThe healer's hands bring comfort to the ill\n",
#  "A rhymed couplet:\nThe butterfly emerges from cocoon\nTransformed completely, like the changing moon\n\nA rhymed couplet:\nThe runner's breath, in clouds upon the air\n"]

# %%
"""
Steer on new-line
"""

# %%
for prompt in [
    "A rhyming couplet:\nSweet and sticky, a desert treat so great\n",
]

# %%
a_pear_questions_one_shot_suggestive[0]
# Out:
# "Answer the qustion using the correct article:\nWhat fruit is really sour?\nA lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nAn avocado\n\nAnswer the qustion using the correct article:\nWhat fruit is traditionally the first item in the song 'The Twelve Days of Christmas' (a partridge in...)?"

# %%
# save steering vector
steering_vector = get_steering_vector_fast(model, tokenizer, a_pear_questions_one_shot_suggestive, a_date_questions_one_shot_suggestive, 27)
torch.save(steering_vector, "steering_vectors/steering_vector_a_date_to_a_pear_layer_27.pt")

# %%
a_pear_or_an_apple_questions_one_shot[12]
# Out:
# 'Answer the qustion using the correct article:\nWhat fruit is really sour?\nA lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nAn avocado\n\nAnswer the qustion using the correct article:\nWhat fruit might be featured in a still life painting?'

# %%
a_pear_or_an_apple_questions_one_shot_the[12]
# Out:
# 'Answer the qustion using the article "the":\nWhat fruit is really sour?\nThe lemon\n\nAnswer the qustion using the article "the":\nWhat fruit is guacamole made of?\nThe avocado\n\nAnswer the qustion using the article "the":\nWhat fruit might be featured in a still life painting?'

# %%
a_date_or_a_pear_questions_one_shot[6]
# Out:
# 'Answer the qustion using the correct article:\nWhat fruit is really sour?\nA lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nAn avocado\n\nAnswer the qustion using the correct article:\nWhat fruit is sometimes used as a natural sugar substitute in recipes?'

# %%
print("hello")
# Out:
# hello

# %%
# get token for apple

# %%
# !mkdir steering_vectors
# Out:
# mkdir: cannot create directory ‘steering_vectors’: File exists
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
def analyze_layers_for_wordlists(model, tokenizer, negative_prompts_list, positive_prompts, 
                               generation_prompt, wordlists_dict, 
                               num_layers=1, batch_size=500, steering_multiplier=1.0,save_vectors=False, num_examples=0, extra_line=True, num_words=1):
    """
    Analyze steering effects across layers for multiple wordlists and negative prompts.
    
    Args:
        model: The language model
        tokenizer: The tokenizer for the model
        negative_prompts_list: List of negative prompts variants for steering
        positive_prompts: Positive prompts for steering
        generation_prompt: The prompt to generate completions from
        wordlists_dict: Dictionary of wordlists to analyze {name: wordlist}
        num_layers: Number of layers to analyze
        batch_size: batch_size
        steering_multiplier: Multiplier for steering vector
        num_examples: Number of examples provided in the prompt (zero-shot, one-shot, two-shot, etc.)
        num_words: Number of words to consider in the last word
    Returns:
        DataFrame with analysis results
    """
    results = []
    
    for neg_prompt_idx, negative_prompts in enumerate(negative_prompts_list):
        neg_prompt_name = f"neg_prompt_v{neg_prompt_idx+1}"
        print(f"Processing negative prompt variant: {neg_prompt_name}")
        
        for layer in tqdm(range(num_layers), desc=f"Analyzing layers for {neg_prompt_name}"):
            # print(f"Layer {layer}")
            
            # Get steering vector for this layer with current negative prompt variant
            steering_vector = get_steering_vector_fast(
                model, tokenizer, negative_prompts, positive_prompts, layer=layer
            )

            if save_vectors: torch.save(steering_vector,f"steering_vectors_quick_to_pain/steering_vector_quick_to_pain_layer_{layer}.pt")
            
            # Generate text with positive and negative steering
            steered_text = generate_steered_output(
                steering_vector, model, tokenizer, generation_prompt, 
                batch_size, layer=layer, steering_multiplier=steering_multiplier
            )
            
            negsteered_text = generate_steered_output(
                -steering_vector, model, tokenizer, generation_prompt, 
                batch_size, layer=layer, steering_multiplier=steering_multiplier
            )
            
            # Analyze each wordlist
            for wordlist_name, wordlist in wordlists_dict.items():
                # Get fractions for positive steering
                pos_fraction = get_last_word_fraction(steered_text, wordlist, num_examples=num_examples, extra_line=extra_line, num_words=num_words)
                
                # Get fractions for negative steering
                neg_fraction = get_last_word_fraction(negsteered_text, wordlist, num_examples=num_examples, extra_line=extra_line, num_words=num_words)
                
                # Store results
                results.append({
                    "layer": layer,
                    "wordlist": wordlist_name,
                    "steering": "positive",
                    "neg_prompt_variant": neg_prompt_name,
                    "last_word_fraction": pos_fraction
                })
                
                results.append({
                    "layer": layer,
                    "wordlist": wordlist_name,
                    "steering": "negative",
                    "neg_prompt_variant": neg_prompt_name,
                    "last_word_fraction": neg_fraction
                })
    
    # Convert to DataFrame
    return pd.DataFrame(results)

def plot_layer_analysis(results_df):
    """
    Plot the results of layer analysis with multiple negative prompt variants.
    
    Args:
        results_df: DataFrame with analysis results
    """
    wordlists = results_df["wordlist"].unique()
    neg_prompt_variants = results_df["neg_prompt_variant"].unique()
    
    # Create figure with subplots - one row per wordlist
    fig, axes = plt.subplots(nrows=len(wordlists), figsize=(14, 5*len(wordlists)))
    if len(wordlists) == 1:
        axes = [axes]  # Make iterable for single subplot
    
    # Colors for different variants
    colors = ['blue', 'green', 'purple', 'orange', 'brown', 'pink']
    
    # Plot each wordlist in its own subplot
    for i, wordlist in enumerate(wordlists):
        wordlist_data = results_df[results_df["wordlist"] == wordlist]
        
        for v_idx, variant in enumerate(neg_prompt_variants):
            variant_data = wordlist_data[wordlist_data["neg_prompt_variant"] == variant]
            
            # Get positive and negative steering data for this variant
            pos_data = variant_data[variant_data["steering"] == "positive"]
            neg_data = variant_data[variant_data["steering"] == "negative"]
            
            # Plot with distinct colors and markers for each variant
            color = colors[v_idx % len(colors)]
            axes[i].plot(pos_data["layer"], pos_data["last_word_fraction"], 
                        label=f"{variant} - Positive", marker='o', linestyle='-', color=color)
            axes[i].plot(neg_data["layer"], neg_data["last_word_fraction"], 
                        label=f"{variant} - Negative", marker='x', linestyle='--', color=color)
        
        axes[i].set_title(f"Wordlist: {wordlist}")
        axes[i].set_xlabel("Layer")
        axes[i].set_ylabel("Last Word Fraction")
        axes[i].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        axes[i].grid(True, alpha=0.3)
    
    plt.tight_layout()
    return fig

def plot_comparative_analysis(results_df):
    """
    Plot comparison between negative prompt variants for each wordlist.
    
    Args:
        results_df: DataFrame with analysis results
    """
    wordlists = results_df["wordlist"].unique()
    neg_prompt_variants = results_df["neg_prompt_variant"].unique()
    
    if len(neg_prompt_variants) < 2:
        print("Need at least 2 negative prompt variants for comparison")
        return None
    
    # Create a figure with 2 rows per wordlist (pos and neg steering)
    fig, axes = plt.subplots(
        nrows=2*len(wordlists), 
        figsize=(14, 4*len(wordlists)),
        squeeze=False
    )
    
    for w_idx, wordlist in enumerate(wordlists):
        wordlist_data = results_df[results_df["wordlist"] == wordlist]
        
        # First row: Positive steering comparison
        pos_row = w_idx * 2
        pos_data = wordlist_data[wordlist_data["steering"] == "positive"]
        
        for v_idx, variant in enumerate(neg_prompt_variants):
            variant_pos = pos_data[pos_data["neg_prompt_variant"] == variant]
            axes[pos_row, 0].plot(
                variant_pos["layer"], 
                variant_pos["last_word_fraction"],
                label=variant,
                marker='o' if v_idx == 0 else 'x'
            )
        
        axes[pos_row, 0].set_title(f"{wordlist} - Positive Steering Comparison")
        axes[pos_row, 0].set_xlabel("Layer")
        axes[pos_row, 0].set_ylabel("Last Word Fraction")
        axes[pos_row, 0].legend()
        axes[pos_row, 0].grid(True, alpha=0.3)
        
        # Second row: Negative steering comparison
        neg_row = w_idx * 2 + 1
        neg_data = wordlist_data[wordlist_data["steering"] == "negative"]
        
        for v_idx, variant in enumerate(neg_prompt_variants):
            variant_neg = neg_data[neg_data["neg_prompt_variant"] == variant]
            axes[neg_row, 0].plot(
                variant_neg["layer"], 
                variant_neg["last_word_fraction"],
                label=variant,
                marker='o' if v_idx == 0 else 'x'
            )
        
        axes[neg_row, 0].set_title(f"{wordlist} - Negative Steering Comparison")
        axes[neg_row, 0].set_xlabel("Layer")
        axes[neg_row, 0].set_ylabel("Last Word Fraction")
        axes[neg_row, 0].legend()
        axes[neg_row, 0].grid(True, alpha=0.3)
    
    plt.tight_layout()
    return fig

# %%
from dataclasses import dataclass

# %%
def save_and_plot_results(results, filename):
    # Save results to CSV for future analysis
    results.to_csv(filename, index=False)
        
        # Plot combined results
    fig1 = plot_layer_analysis(results)
    plt.savefig(filename, dpi=300)
        
        # Plot comparative analysis
    fig2 = plot_comparative_analysis(results)
    plt.savefig(filename, dpi=300)
        
    plt.show()

def run_analysis(cfg: SteeringExperimentConfig):
    print(f"Running analysis for {cfg.experiment_name}")
    results = analyze_layers_for_wordlists(
        model=model,
        tokenizer=tokenizer,
        negative_prompts_list=[cfg.negative_prompts],
        positive_prompts=cfg.positive_prompts,
        generation_prompt=cfg.generation_prompt,
        wordlists_dict=cfg.wordlists,
        num_layers=model.config.num_hidden_layers,
        batch_size=500,
        steering_multiplier=cfg.steering_multiplier,
        save_vectors=cfg.save_vectors,
        num_examples=cfg.num_examples,
        extra_line=cfg.extra_line,
        num_words=cfg.num_words,
    )
    save_and_plot_results(results, f"layer_analysis_results_{cfg.experiment_name}.png")
    return results

# %%
MAX_NEW_TOKENS = 6

# %%
# Define all the Experiment Configs

# Quick to Pain / (maybe Pain to Quick ...)
cfg_quick_to_pain = SteeringExperimentConfig(
    experiment_name='quick_to_pain',
    generation_prompt='A rhymed couplet:\nA leopard appeared, fierce and quick\n',
    positive_prompts=get_prompts(lines_that_rhyme_with_quick),
    negative_prompts=get_prompts(lines_that_rhyme_with_pain),
    wordlists={
        "all_quick_rhymes": quick_rhymes_all,
        "all_pain_rhymes": pain_rhymes_all,
        "quick": ["quick"],
        "stick": ["stick"],
        "trick": ["trick"],
        "rain": ["rain"],
        "pain": ["pain"],
        "crane": ["crane"],
    }
)

# Rabbit to Habit Cheating
cfg_rabbit_to_habit_cheating = SteeringExperimentConfig(
    experiment_name='rabbit_to_habit_cheating',
    generation_prompt='A rhymed couplet:\nHe saw a carrot and had to grab it\n',
    positive_prompts=[f"A rhymed couplet that ends with rabbit:\n{line}" for line in lines_that_rhyme_with_rabbit_general],
    negative_prompts=[f"A rhymed couplet that ends with habit:\n{line}" for line in lines_that_rhyme_with_habit_general],
    wordlists={
        "rabbit": ["rabbit"],
        "habit": ["habit"],
    }
)

# Rabbit to Habit Oneshot
cfg_rabbit_to_habit_oneshot = SteeringExperimentConfig(
    experiment_name='rabbit_to_habit_oneshot',
    generation_prompt='A rhymed couplet:\nHe saw a carrot and had to grab it\n',
    positive_prompts=lines_that_rhyme_with_rabbit_oneshot,
    negative_prompts=lines_that_rhyme_with_habit_oneshot,
    wordlists={
        "rabbit": ["rabbit"],
        "habit": ["habit"],
    }
)

# Quick to unrhymed
cfg_quick_to_unrhymed = SteeringExperimentConfig(
    experiment_name='quick_to_unrhymed',
    generation_prompt=example_based_unrhymed_prompts_quick[10],
    positive_prompts=example_based_unrhymed_prompts_quick,
    negative_prompts=example_based_rhymed_prompts_quick,
    wordlists={
        "all_quick_rhymes": quick_rhymes_all,
        "all_pain_rhymes": pain_rhymes_all,
        "quick": ["quick"],
        "stick": ["stick"],
        "trick": ["trick"],
        "rain": ["rain"],
        "pain": ["pain"],
        "mane": ["mane"],
    },
    num_examples=1,
    extra_line=False,
)

one_shot_prompt = "Uses sand to measure time:\nAn hourglass"
rabbit_one_shot_prompts = [one_shot_prompt + "\n\n" + line for line in a_rabbit_questions]
habit_one_shot_prompts = [one_shot_prompt + "\n\n" + line for line in a_habit_questions]
ape_one_shot_prompts = [one_shot_prompt + "\n\n" + line for line in an_ape_questions]

# a / an generalization
cfg_a_an_generalization = SteeringExperimentConfig(
    experiment_name='a_an_generalization',
    generation_prompt='A rhymed couplet:\nHe saw a carrot and had to grab it\n',
    positive_prompts=rabbit_one_shot_prompts,
    negative_prompts=habit_one_shot_prompts,
    wordlists={
        "rabbit": ["rabbit"],
        "habit": ["habit"],
    },
    num_examples=0,
)

a_rabbit_questions_and_article_one_shot = [line + "A " for line in rabbit_one_shot_prompts]
a_habit_questions_and_article_one_shot = [line + "A " for line in habit_one_shot_prompts]
an_ape_questions_and_article_one_shot = [line + "An " for line in ape_one_shot_prompts]

# a / an generalization with article
cfg_a_an_generalization_with_article = SteeringExperimentConfig(
    experiment_name='a_an_generalization_with_article',
    generation_prompt='A rhymed couplet:\nHe saw a carrot and had to grab it\n',
    positive_prompts=a_rabbit_questions_and_article_one_shot,
    negative_prompts=a_habit_questions_and_article_one_shot,
    wordlists={
        "rabbit": ["rabbit"],
        "habit": ["habit"],
    },
    num_examples=0,
)

cfg_brick_to_rain = SteeringExperimentConfig(
    experiment_name='brick_to_rain',
    generation_prompt='A rhymed couplet:\nThe house was built with sturdy, reddish brick\n',
    positive_prompts=get_prompts(lines_that_rhyme_with_pain),
    negative_prompts=get_prompts(lines_that_rhyme_with_quick),
    wordlists = {
        "all_brick_rhymes": quick_rhymes_all,
        "all_rain_rhymes": pain_rhymes_all,
        "quick": ["quick"],
        "trick": ["trick"],
        "pain": ["pain"],
        "rain": ["rain"],
    },
    num_examples=0,
    extra_line=True,
)

cfg_an_apple_to_a_pear_1_5 = SteeringExperimentConfig(
    experiment_name='an_apple_to_a_pear',
    generation_prompt=a_pear_or_an_apple_questions_one_shot[12],
    positive_prompts=a_pear_questions_one_shot_suggestive,
    negative_prompts=an_apple_questions_one_shot_suggestive,
    # positive_words=["pear"],
    # negative_words=["apple"],
    # layer=27,
    steering_multiplier=2.0,
    num_examples=2,
    extra_line=True,
    batch_size=1000,
    # batch_size=200,
    wordlists={
        "an apple": ["an apple"],
        "a pear": ["a pear"],
    },
    num_words=2,
)

cfg_a_date_to_a_pear_1_5 = SteeringExperimentConfig(
    experiment_name='a_date_to_a_pear',
    generation_prompt=a_date_or_a_pear_questions_one_shot[6],
    positive_prompts=a_pear_questions_one_shot_suggestive,
    negative_prompts=a_date_questions_one_shot_suggestive,
    steering_multiplier=2.0,
    num_examples=2,
    extra_line=True,
    batch_size=1000,
    wordlists={
        "a date": ["a date"],
        "a pear": ["a pear"],
    },
    num_words=2,
)

cfg_an_apple_to_a_pear_the_answer_is_1_5 = SteeringExperimentConfig(
    experiment_name='an_apple_to_a_pear_the_answer_is',
    generation_prompt=a_pear_or_an_apple_questions_one_shot_the_answer_is[12],
    positive_prompts=a_pear_questions_one_shot_the_answer_is_suggestive,
    negative_prompts=an_apple_questions_one_shot_the_answer_is_suggestive,
    # positive_words=["pear"],
    # negative_words=["apple"],
    # layer=27,
    steering_multiplier=2.0,
    num_examples=2,
    extra_line=True,
    batch_size=1000,
    wordlists={
        "an apple": ["an apple"],
        "a pear": ["a pear"],
    },
    num_words=2,
)

cfg_an_apple_to_a_pear_the_1_5 = SteeringExperimentConfig(
    experiment_name='an_apple_to_a_pear_the',
    generation_prompt=a_pear_or_an_apple_questions_one_shot_the[12],
    positive_prompts=a_pear_questions_one_shot_suggestive,
    negative_prompts=an_apple_questions_one_shot_suggestive,
    # positive_words=["pear"],
    # negative_words=["apple"],
    # layer=27,
    steering_multiplier=2.0,
    num_examples=2,
    extra_line=True,
    batch_size=1000,
    wordlists={
        "the apple": ["the apple"],
        "the pear": ["the pear"],
        "a pear": ["a pear"],
        "an apple": ["an apple"],
    },
    num_words=2,
)

cfg_an_apple_to_a_pear_the_1_5_no_generalization = SteeringExperimentConfig(
    experiment_name='an_apple_to_a_pear_the_1_5_no_generalization',
    generation_prompt=a_pear_or_an_apple_questions_one_shot_the[12],
    positive_prompts=a_pear_questions_one_shot_the_suggestive,
    negative_prompts=an_apple_questions_one_shot_the_suggestive,
    # positive_words=["pear"],
    # negative_words=["apple"],
    # layer=27,
    steering_multiplier=2.0,
    num_examples=2,
    extra_line=True,
    batch_size=1000,
    wordlists={
        "the apple": ["the apple"],
        "the pear": ["the pear"],
    },
    num_words=2,
)

# %%
a_pear_or_an_apple_questions_one_shot[12]
# Out:
# 'Answer the qustion using the correct article:\nWhat fruit is really sour?\nA lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nAn avocado\n\nAnswer the qustion using the correct article:\nWhat fruit might be featured in a still life painting?'

# %%
a_date_or_a_pear_questions_one_shot[6]
# Out:
# 'Answer the qustion using the correct article:\nWhat fruit is really sour?\nA lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nAn avocado\n\nAnswer the qustion using the correct article:\nWhat fruit is sometimes used as a natural sugar substitute in recipes?'

# %%
a_pear_or_an_apple_questions_one_shot_the_answer_is[12]
# Out:
# 'Answer the qustion using the correct article:\nWhat fruit is really sour?\nThe answer is a lemon\n\nAnswer the qustion using the correct article:\nWhat fruit is guacamole made of?\nThe answer is an avocado\n\nAnswer the qustion using the correct article:\nWhat fruit might be featured in a still life painting?'

# %%
a_pear_or_an_apple_questions_one_shot_the[12]
# Out:
# 'Answer the qustion using the article "the":\nWhat fruit is really sour?\nThe lemon\n\nAnswer the qustion using the article "the":\nWhat fruit is guacamole made of?\nThe avocado\n\nAnswer the qustion using the article "the":\nWhat fruit might be featured in a still life painting?'

# %%
MAX_NEW_TOKENS = 6

# %%
run_analysis(cfg_an_apple_to_a_pear_1_5)
run_analysis(cfg_a_date_to_a_pear_1_5)
run_analysis(cfg_an_apple_to_a_pear_the_answer_is_1_5)
# Out:
# Running analysis for an_apple_to_a_pear
# Processing negative prompt variant: neg_prompt_v1
# Analyzing layers for neg_prompt_v1: 100%|██████████| 42/42 [03:45<00:00,  5.38s/it]
# Need at least 2 negative prompt variants for comparison
# Running analysis for a_date_to_a_pear
# Processing negative prompt variant: neg_prompt_v1
# Analyzing layers for neg_prompt_v1: 100%|██████████| 42/42 [03:47<00:00,  5.43s/it]
# Need at least 2 negative prompt variants for comparison
# Running analysis for an_apple_to_a_pear_the_answer_is
# Processing negative prompt variant: neg_prompt_v1
# Analyzing layers for neg_prompt_v1: 100%|██████████| 42/42 [03:53<00:00,  5.57s/it]
# Need at least 2 negative prompt variants for comparison
#      layer  wordlist  steering neg_prompt_variant  last_word_fraction
# 0        0  an apple  positive      neg_prompt_v1               0.350
# 1        0  an apple  negative      neg_prompt_v1               0.450
# 2        0    a pear  positive      neg_prompt_v1               0.620
# 3        0    a pear  negative      neg_prompt_v1               0.534
# 4        1  an apple  positive      neg_prompt_v1               0.336
# ..     ...       ...       ...                ...                 ...
# 163     40    a pear  negative      neg_prompt_v1               0.642
# 164     41  an apple  positive      neg_prompt_v1               0.182
# 165     41  an apple  negative      neg_prompt_v1               0.232
# 166     41    a pear  positive      neg_prompt_v1               0.424
# 167     41    a pear  negative      neg_prompt_v1               0.520
#
# [168 rows x 5 columns]

# %%
# cfg_quick_to_pain, cfg_rabbit_to_habit_cheating, cfg_rabbit_to_habit_oneshot, cfg_quick_to_unrhymed, cfg_rhyming_to_unrhyming, cfg_a_an_generalization, cfg_a_an_generalization_with_article
# run_analysis(cfg_quick_to_pain)
# run_analysis(cfg_rabbit_to_habit_cheating)
# run_analysis(cfg_rabbit_to_habit_oneshot)
# run_analysis(cfg_quick_to_unrhymed)
# run_analysis(cfg_rhyming_to_unrhyming)
# run_analysis(cfg_a_an_generalization)
# run_analysis(cfg_a_an_generalization_with_article)
# run_analysis(cfg_brick_to_rain)
run_analysis(cfg_an_apple_to_a_pear_1_5)
run_analysis(cfg_a_date_to_a_pear_1_5)
run_analysis(cfg_an_apple_to_a_pear_the_answer_is_1_5)
run_analysis(cfg_an_apple_to_a_pear_the_1_5)
run_analysis(cfg_an_apple_to_a_pear_the_1_5_no_generalization)
# run_analysis(cfg_an_apple_to_a_pear_the_answer_is_1_5)
# Out:
# Running analysis for an_apple_to_a_pear
# Processing negative prompt variant: neg_prompt_v1
# Analyzing layers for neg_prompt_v1: 100%|██████████| 42/42 [03:34<00:00,  5.10s/it]
# Need at least 2 negative prompt variants for comparison
# Running analysis for a_date_to_a_pear
# Processing negative prompt variant: neg_prompt_v1
# Analyzing layers for neg_prompt_v1: 100%|██████████| 42/42 [03:42<00:00,  5.29s/it]
# Need at least 2 negative prompt variants for comparison
# Running analysis for an_apple_to_a_pear_the_answer_is
# Processing negative prompt variant: neg_prompt_v1
# Analyzing layers for neg_prompt_v1: 100%|██████████| 42/42 [03:45<00:00,  5.38s/it]
# Need at least 2 negative prompt variants for comparison
# Running analysis for an_apple_to_a_pear_the
# Processing negative prompt variant: neg_prompt_v1
# Analyzing layers for neg_prompt_v1: 100%|██████████| 42/42 [03:39<00:00,  5.22s/it]
# Need at least 2 negative prompt variants for comparison
# Running analysis for an_apple_to_a_pear_the_1_5_no_generalization
# Processing negative prompt variant: neg_prompt_v1
# Analyzing layers for neg_prompt_v1: 100%|██████████| 42/42 [03:40<00:00,  5.25s/it]
# Need at least 2 negative prompt variants for comparison
# Running analysis for an_apple_to_a_pear_the_answer_is
# Processing negative prompt variant: neg_prompt_v1
# Analyzing layers for neg_prompt_v1: 100%|██████████| 42/42 [03:45<00:00,  5.36s/it]
# Need at least 2 negative prompt variants for comparison
#      layer wordlist  steering neg_prompt_variant  last_word_fraction
# 0        0    apple  positive      neg_prompt_v1               0.320
# 1        0    apple  negative      neg_prompt_v1               0.490
# 2        0     pear  positive      neg_prompt_v1               0.654
# 3        0     pear  negative      neg_prompt_v1               0.494
# 4        1    apple  positive      neg_prompt_v1               0.360
# ..     ...      ...       ...                ...                 ...
# 163     40     pear  negative      neg_prompt_v1               0.654
# 164     41    apple  positive      neg_prompt_v1               0.180
# 165     41    apple  negative      neg_prompt_v1               0.232
# 166     41     pear  positive      neg_prompt_v1               0.416
# 167     41     pear  negative      neg_prompt_v1               0.462
#
# [168 rows x 5 columns]

# %%
generation_prompt=a_pear_or_an_apple_qustions_one_shot[12]
